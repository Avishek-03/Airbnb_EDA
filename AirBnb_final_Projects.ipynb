# %% [markdown]
# <a href="https://colab.research.google.com/github/Avishek-03/Airbnb_EDA/blob/main/AirBnb_final_Projects.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name**    -

# %% [markdown]
# ##### **Project Type**    - EDA
# ##### **Contribution**    - Individual
# ##### **Team Member 1 -** Avishek Dash

# %% [markdown]
# # **Project Overview -**
#
#
# Airbnb is an American company that operate an online marketplace that connects people who want to rent out their properties with travelers seeking accommodations. Founded in 2008, Airbnb allows individuals to list their homes, apartments, or even just a spare room for short-term rentals. Travelers can then search for these listings based on location, price, amenities, and other criteria. It has expanded rapidly over the years and now operates in thousands of cities and countries worldwide, offering a wide range of lodging options to suit different preferences and budgets.
#
#  Data analysis on millions of listings provided through Airbnb is a crucial factor for the company. These millions of listings generate a lot of data, that can be analyzed and used for security, business decisions, understanding of customers and hosts behavior and performance on the platform, guiding marketing initiatives, implementation of innovative additional services and much more.
#
# This dataset has total around 49,000 observation rows with 16 columns and it is a mix between numeric and categorical values.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# https://github.com/Avishek-03/Airbnb_EDA

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# 1.What can we learn about different hosts and areas?
#
# 2.What is the count of properties of each room type?
#
# 3.Which hosts are the busiest and why?
#
# 4.What is the average price for each neighborhood group?
#
# 5.what is the correlation between different variable?
#
# 6.What can we learn from predictions? (ex: locations, prices, reviews, etc)

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import pandas as pd                   #Importing Pandas library
import numpy as np                    #Importing Numpy library
import matplotlib.pyplot as plt       #Importing Matplot library
import seaborn as sns                 #Importing Seaborn library
import missingno as msno              #Importing missingno library to visualize Nan Values

# %% [markdown]
# ### Dataset Loading

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Load Dataset
bnb_df=pd.read_csv('/content/drive/MyDrive/Copy of Airbnb NYC 2019.csv')
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# 0     Private room    149               1                  9  2018-10-19
# 1  Entire home/apt    225               1                 45  2019-05-21
# 2     Private room    150               3                  0         NaN
# 3  Entire home/apt     89               1                270  2019-07-05
# 4  Entire home/apt     80              10                  9  2018-11-19
#
#    reviews_per_month  calculated_host_listings_count  availability_365
# 0               0.21                               6               365
# 1               0.38                               2               355
# 2                NaN                               1               365
# 3               4.64                               1               194
# 4               0.10                               1                 0

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
bnb_df.head(5)
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# 0     Private room    149               1                  9  2018-10-19
# 1  Entire home/apt    225               1                 45  2019-05-21
# 2     Private room    150               3                  0         NaN
# 3  Entire home/apt     89               1                270  2019-07-05
# 4  Entire home/apt     80              10                  9  2018-11-19
#
#    reviews_per_month  calculated_host_listings_count  availability_365
# 0               0.21                               6               365
# 1               0.38                               2               355
# 2                NaN                               1               365
# 3               4.64                               1               194
# 4               0.10                               1                 0

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
Rows,Columns=bnb_df.shape
print( "Rows=",Rows)
print( "Columns=",Columns)
# Out:
# Rows= 48895
# Columns= 16

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
bnb_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48895 non-null  int64
#  1   name                            48879 non-null  object
#  2   host_id                         48895 non-null  int64
#  3   host_name                       48874 non-null  object
#  4   neighbourhood_group             48895 non-null  object
#  5   neighbourhood                   48895 non-null  object
#  6   latitude                        48895 non-null  float64
#  7   longitude                       48895 non-null  float64
#  8   room_type                       48895 non-null  object
#  9   price                           48895 non-null  int64
#  10  minimum_nights                  48895 non-null  int64
#  11  number_of_reviews               48895 non-null  int64
#  12  last_review                     38843 non-null  object
#  13  reviews_per_month               38843 non-null  float64
#  14  calculated_host_listings_count  48895 non-null  int64
#  15  availability_365                48895 non-null  int64
# dtypes: float64(3), int64(7), object(6)
# memory usage: 6.0+ MB

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
bnb_df[bnb_df.duplicated()].sum() #After seeing the output we can tell there is no duplicate rows are present
# Out:
# id                                  0
# name                                0
# host_id                             0
# host_name                           0
# neighbourhood_group                 0
# neighbourhood                       0
# latitude                          0.0
# longitude                         0.0
# room_type                           0
# price                               0
# minimum_nights                      0
# number_of_reviews                   0
# last_review                         0
# reviews_per_month                 0.0
# calculated_host_listings_count      0
# availability_365                    0
# dtype: object

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
bnb_df.isnull().sum()
# Out:
# id                                    0
# name                                 16
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %%
# Visualizing the missing values

msno.matrix(bnb_df)
# msno.heatmap(bnb_df)
# msno.dendrogram(bnb_df)
plt.show()

# %%
# Calculate percentage of missing values for each variable
missing_percentage = (bnb_df.isnull().sum() / len(bnb_df)) * 100

# Create bar plot of missing values
plt.figure(figsize=(8, 4))
missing_percentage.plot(kind='bar', color='skyblue')
plt.title('Percentage of Missing Values by Variable')
plt.xlabel('Variables')
plt.ylabel('Percentage Missing (%)')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# This bar plot will display variables on the x-axis and the percentage of missing values on the y-axis. It allow us to quickly identify Variables with high levels of missing data.

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# Based on the provided information, it is evident that the columns host_name, neighbourhood_group, reviews_per_month, neighbourhood, and room_type are all of object type. Conversely, all remaining columns are either of integer or float type.
# **There are some columns which have null values.**
#
#
#
# *   name:16
# *   host_name:21
# *   last_review:10052
# *   reviews_per_month:10052

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
bnb_df.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365'],
#       dtype='object')

# %%
# Dataset Describe
#  df.describe(include='all')
bnb_df.describe()
# Out:
#                  id       host_id      latitude     longitude         price  \
# count  4.889500e+04  4.889500e+04  48895.000000  48895.000000  48895.000000
# mean   1.901714e+07  6.762001e+07     40.728949    -73.952170    152.720687
# std    1.098311e+07  7.861097e+07      0.054530      0.046157    240.154170
# min    2.539000e+03  2.438000e+03     40.499790    -74.244420      0.000000
# 25%    9.471945e+06  7.822033e+06     40.690100    -73.983070     69.000000
# 50%    1.967728e+07  3.079382e+07     40.723070    -73.955680    106.000000
# 75%    2.915218e+07  1.074344e+08     40.763115    -73.936275    175.000000
# max    3.648724e+07  2.743213e+08     40.913060    -73.712990  10000.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count    48895.000000       48895.000000       38843.000000
# mean         7.029962          23.274466           1.373221
# std         20.510550          44.550582           1.680442
# min          1.000000           0.000000           0.010000
# 25%          1.000000           1.000000           0.190000
# 50%          3.000000           5.000000           0.720000
# 75%          5.000000          24.000000           2.020000
# max       1250.000000         629.000000          58.500000
#
#        calculated_host_listings_count  availability_365
# count                    48895.000000      48895.000000
# mean                         7.143982        112.781327
# std                         32.952519        131.622289
# min                          1.000000          0.000000
# 25%                          1.000000          0.000000
# 50%                          1.000000         45.000000
# 75%                          2.000000        227.000000
# max                        327.000000        365.000000

# %% [markdown]
# ### Variables Description

# %% [markdown]
# **The following columns are listed in the DataFrame-**
#
#
#
# *   ID(int64) - ID of the person who booked the Airbnb.
# *   Name(object) - Name of the person who booked accommodation.
# *  host_id(int64) - ID of the person who rents out the property.
# *  Host_name(object) - Name of the person who rents out their property.
# *   neighbourhood_group(object)- It indicates the region that includes several
# *   small neighborhoods (i.e.like a broader group having smaller units of neighborhood).
# *  Neighborhood(object) - It indicates the geographically smaller areas within a city or region having their own local identity and characteristics
# *   Latitude(float64) - Shows the measurement of the distance from the north or south pole of an equator of that particular property.
# *  Longitude(float64) - Shows the measurement of distance from the east or west prime meridian of that particular property.
# *  room_type(object) - Indicates the type of the room i.e. private room, Entire home/apt, or shared room.
# *   price(int64) - This indicates the value at which the property is rented in bucks.
# *  minimum_nights(int64) - This shows the minimum nights offered by the host (i.e. a person can't book for less than this set number of nights)
# *   number_of_reviews(int64) - This indicates the number of reviews received by a particular property.
# *   last_review(object) - Shows the last date of the review given
# *  reviews_per_month(float64) - It indicates the number of reviews given in a particular month.
# *   calculated_host_listings_count(int64)- It shows the count of listings per host.
# *   availability_365(int64) - It indicates for how many days the Airbnb is available in a year.
#
#
#
#
#
#
#
#
#
# .

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
for i in bnb_df.columns.tolist():
  print(i,"-",bnb_df[i].nunique())
# Out:
# id - 48895
# name - 47905
# host_id - 37457
# host_name - 11452
# neighbourhood_group - 5
# neighbourhood - 221
# latitude - 19048
# longitude - 14718
# room_type - 3
# price - 674
# minimum_nights - 109
# number_of_reviews - 394
# last_review - 1764
# reviews_per_month - 937
# calculated_host_listings_count - 47
# availability_365 - 366

# %%
def unique_values_count():
  ''' This function will return the dictionary in which
  keys denotes the column name and its values denotes the
  unique value counts'''
  di={}
  for i in bnb_df.columns:
    count=bnb_df[i].unique()
    di[i]=len(count)
  return di

unique_count=unique_values_count()

#Taking user input
col_name_u=input("Enter column name: ").lower()

#Printing the output for unique value counts
print(unique_count[col_name_u])
# Out:
# Enter column name: id
# 48895

# %%
def unique_values_count(df):
    return df.nunique()

# Call the function to get the counts of unique values in each column
unique_count = unique_values_count(bnb_df)

# Taking input(column name) from user
col_name_u = input("Enter column name: ").lower()

# Printing the output for unique value counts
print(unique_count.get(col_name_u,"Column not found"))
# Out:
# Enter column name: id
# 48895

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Drop the unwanted columns and NaN values
bnb_df.drop(['last_review','reviews_per_month'],axis=1,inplace=True)    #Bcoz these two column contains mostly null values
bnb_df.dropna(inplace=True)

# %%
bnb_df.head(5)
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews  \
# 0     Private room    149               1                  9
# 1  Entire home/apt    225               1                 45
# 2     Private room    150               3                  0
# 3  Entire home/apt     89               1                270
# 4  Entire home/apt     80              10                  9
#
#    calculated_host_listings_count  availability_365
# 0                               6               365
# 1                               2               355
# 2                               1               365
# 3                               1               194
# 4                               1                 0

# %%
#Check for null values after cleaning
bnb_df.isnull().sum()
# Out:
# id                                0
# name                              0
# host_id                           0
# host_name                         0
# neighbourhood_group               0
# neighbourhood                     0
# latitude                          0
# longitude                         0
# room_type                         0
# price                             0
# minimum_nights                    0
# number_of_reviews                 0
# calculated_host_listings_count    0
# availability_365                  0
# dtype: int64

# %%
#Printing the shape of dataset after handling null values
rows,columns=bnb_df.shape
print("Rows=",rows)
print("Columns=",columns)
# Out:
# Rows= 48858
# Columns= 14

# %%
def unique_item(x):
  '''This function return the unique item
  in a given column'''

  return bnb_df[x].unique()

#Taking input from user
col_name=input("Enter the column name: ").lower()

#Printing the output for unique item in a sorted way
print(np.sort(unique_item(col_name)))
# Out:
# Enter the column name: id
# [    2539     2595     3647 ... 36485431 36485609 36487245]

# %%
def outlier_plot(x):

  '''This function will take the column name
  of a given dataset and plot the boxplot for it.'''

  sns.boxplot(bnb_df[x])
  plt.ylabel(x)
  return plt.show()

#Taking input from user for which column they want
col=input("Enter col name: ").lower()

#Print the plot
print(outlier_plot(col))
# Out:
# Enter col name: price
# None

# %%
# Removing Outliers from minimum_nights columns as we can see in box plot
bnb_df.drop(bnb_df[bnb_df['minimum_nights']>=600].index,inplace=True)

# %%
# We have price is 0 for some entries so we have to counter it
mode_ds=bnb_df['price'].mode()

#Replacing 0 price withe mode value and reflecting in main dataset only
bnb_df['price'].replace(to_replace=0,value=mode_ds[0],inplace=True)
print(mode_ds[0])
bnb_df.head(10)
# Out:
# 100
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
# 5  5099         Large Cozy 1 BR Apartment In Midtown East     7322
# 6  5121                                   BlissArtsSpace!     7356
# 7  5178                  Large Furnished Room Near B'way      8967
# 8  5203                Cozy Clean Guest Room - Family Apt     7490
# 9  5238                Cute & Cozy Lower East Side 1 bdrm     7549
#
#      host_name neighbourhood_group       neighbourhood  latitude  longitude  \
# 0         John            Brooklyn          Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan             Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan              Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn        Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan         East Harlem  40.79851  -73.94399
# 5        Chris           Manhattan         Murray Hill  40.74767  -73.97500
# 6        Garon            Brooklyn  Bedford-Stuyvesant  40.68688  -73.95596
# 7     Shunichi           Manhattan      Hell's Kitchen  40.76489  -73.98493
# 8    MaryEllen           Manhattan     Upper West Side  40.80178  -73.96723
# 9          Ben           Manhattan           Chinatown  40.71344  -73.99037
#
#          room_type  price  minimum_nights  number_of_reviews  \
# 0     Private room    149               1                  9
# 1  Entire home/apt    225               1                 45
# 2     Private room    150               3                  0
# 3  Entire home/apt     89               1                270
# 4  Entire home/apt     80              10                  9
# 5  Entire home/apt    200               3                 74
# 6     Private room     60              45                 49
# 7     Private room     79               2                430
# 8     Private room     79               2                118
# 9  Entire home/apt    150               1                160
#
#    calculated_host_listings_count  availability_365
# 0                               6               365
# 1                               2               355
# 2                               1               365
# 3                               1               194
# 4                               1                 0
# 5                               1               129
# 6                               1                 0
# 7                               1               220
# 8                               1                 0
# 9                               4               188

# %%
# We have availability_365 as 0 for many entries so we have to handle it
mean_ds=bnb_df['availability_365'].mean()

#Replacing 0 availability_365 withe mean value and reflecting in main dataset only
bnb_df['availability_365'].replace(to_replace=0,value=round(mean_ds),inplace=True)
print(round(mean_ds))
bnb_df.head(10)
# Out:
# 113
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
# 5  5099         Large Cozy 1 BR Apartment In Midtown East     7322
# 6  5121                                   BlissArtsSpace!     7356
# 7  5178                  Large Furnished Room Near B'way      8967
# 8  5203                Cozy Clean Guest Room - Family Apt     7490
# 9  5238                Cute & Cozy Lower East Side 1 bdrm     7549
#
#      host_name neighbourhood_group       neighbourhood  latitude  longitude  \
# 0         John            Brooklyn          Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan             Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan              Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn        Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan         East Harlem  40.79851  -73.94399
# 5        Chris           Manhattan         Murray Hill  40.74767  -73.97500
# 6        Garon            Brooklyn  Bedford-Stuyvesant  40.68688  -73.95596
# 7     Shunichi           Manhattan      Hell's Kitchen  40.76489  -73.98493
# 8    MaryEllen           Manhattan     Upper West Side  40.80178  -73.96723
# 9          Ben           Manhattan           Chinatown  40.71344  -73.99037
#
#          room_type  price  minimum_nights  number_of_reviews  \
# 0     Private room    149               1                  9
# 1  Entire home/apt    225               1                 45
# 2     Private room    150               3                  0
# 3  Entire home/apt     89               1                270
# 4  Entire home/apt     80              10                  9
# 5  Entire home/apt    200               3                 74
# 6     Private room     60              45                 49
# 7     Private room     79               2                430
# 8     Private room     79               2                118
# 9  Entire home/apt    150               1                160
#
#    calculated_host_listings_count  availability_365
# 0                               6               365
# 1                               2               355
# 2                               1               365
# 3                               1               194
# 4                               1               113
# 5                               1               129
# 6                               1               113
# 7                               1               220
# 8                               1               113
# 9                               4               188

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# **What all manipulations have you done and insights you found?**
#
#
# *   The columns last_review and reviews_per_month had large number of null values which contributed a lot to the data and from analysis point of view these columns are of no significance so we dropped these columns.
# *  The rows of the columns named name and host_name had null values and as it is too small to be taken into consideration, hence dropped.
#
#
#
# **The following actions were taken in  codes**
#
#
# *   Initially using the box plot tried to plot every columns to decipher which columns outliers may cause problem for analysis and hence came into conclusion that minimum nights coloumn outliers were to be taken into consideration and hence handled it accordingly.
# *  Handled the invalid value of the price column i.e. 0 , by replacing it with the mode.
# *   Handled the invalid value of availability_365 coloumn i.e. 0 by replacing it with the mean

# %%
bnb_df.to_csv("Final_airbnb.csv")

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1

# %%
# Chart - 1 visualization code
plt.figure(figsize=(6, 4))
c1=sns.histplot(data=bnb_df,x='room_type', color='Steelblue',edgecolor='black')
# c1.grid(False)
plt.title("No. Of Properties of a particular room type")
# Out:
# Text(0.5, 1.0, 'No. Of Properties of a particular room type')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# We take the histogram chart for shows the frequency distributions of each room type.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# We found that the entire home/apt has the high priority in room type beacuse many customers booking entire home/apt room type.The private room has also demaned like entire home/apt but not equal.
#
#  One disadvantage we found customers not intrested in shared room to stay.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?

# %% [markdown]
# Yes, we are able to conclude that shared rooms are not prefered by people so we have to find out why people are not  interested in that category.
# so after that we should try to solve the issue,then we can also see the demand for shared room also.

# %% [markdown]
# #### Chart - 2

# %%
# Chart - 2 visualization code
plt.figure(figsize=(6, 4))
c2=sns.countplot(data=bnb_df,x='neighbourhood_group')
c2.grid(False) # Gridlines that help to read values from the plot.
plt.title("No. Of Properties in a particular neighbourhood group")
# chart2.spines['top'].set_color('black')
# Out:
# Text(0.5, 1.0, 'No. Of Properties in a particular neighbourhood group')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# This graph shows the number of bookings in each neighbourhood group which is a categorical data and categorical data is best shown with the bar graph .

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# It can be concluded that manhatten(neighbourhood group) has the highest number of bookings from others.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
#  We can see that Manhattan is a hotspot for the customers,it attains maximum bookings so we should provide more properties in manhattan to fulfill the increasing demands of people.
#
# On the contrary we can see that Staten Island being the least booked is giving a negative impact which needs to be taken into consideration,so to overcome that impact we should run marketing campaigns or surveys and figure out why this type of pattern is coming.
#
# We should have to consider any stategy through which we increase the customer traffic in this.

# %% [markdown]
# #### Chart - 3

# %%
# Chart - 3 visualization code
plt.figure(figsize=(6, 4))
c3=sns.kdeplot(bnb_df["minimum_nights"])
plt.title("Density listed according to minimum nights")
# Out:
# Text(0.5, 1.0, 'Density listed according to minimum nights')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# This graph shows the density of minimum nights in the dataset,so for depicting this data  kde plot is very suitable graph.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The graph indicates that the majority of bookings fall within the range of 1-10 minimum nights, with a prominent peak in this range. This trend gradually decreases around 20, then shows a slight increase again around 30. Thus, it appears that guests typically prefer booking stays for either a week, 10 days, or a month.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# It's evident that customers primarily lean towards weekly or monthly stays. To capitalize on this trend and maximize property bookings, we might consider urging hosts to prioritize offering rental durations specifically for weekly or monthly intervals.

# %% [markdown]
# #### Chart - 4

# %%
# Chart - 4 The tally of bookings categorized by room type across various neighborhood groups.
sns.set(style="ticks", rc={"axes.grid": False})
c4=sns.catplot(data=bnb_df,x='neighbourhood_group',kind='count',col='room_type')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A graphical representation illustrating the distribution of bookings across room types within various neighborhood groups, using stacked bar graphs for visual clarity.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# It can seen that under private room type ,brooklyn has the highest number of properties,under Entire home/apt room type, manhatten has the highest number of properties and for the shared room type there is no higest demand in all neighbourhood_groups.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# It appears that Staten Island has the lowest number of properties across all room types, followed by the Bronx. Thus, focusing marketing efforts in these areas may stimulate more property rentals. Additionally, Manhattan and Brooklyn show notably fewer bookings in the shared room category compared to other room types. Encouraging hosts to convert shared properties into private rooms could potentially increase bookings, as shared accommodations seem to be less preferred by guests.

# %% [markdown]
# #### Chart - 5

# %%
# Chart - 5 visualization code
c5=(bnb_df.groupby('neighbourhood_group')['neighbourhood'].count()).sort_values(ascending=False)
c5.plot(kind='pie',autopct='%1.1f%%',explode = [0, 0, 0, 0.2,0.3],figsize=(10,5))
plt.title("Percentage of neighbourhood in each neighbourhood_group")
sns.set_palette('tab20')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# This plot shows the percentage of neighbourhood group in each neighbourhood,showing percentage is best suited for pie charts.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# We can infer that manhatten had the most number of neighbourhoods having airbnbs from others.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# As we can conclude from the above graphs that staten island has the least number of properties so therefore we should do advertisements to offer discounts to the host to rent their properties so that we can have more number of properties there.

# %% [markdown]
# #### Chart - 6

# %%
# Chart - 6 visualization code
# # Group by 'neighbourhood_group' and calculate mean price
# avg_price_by_group = bnb_df.groupby('neighbourhood_group')['price'].mean()

# # Convert the result to a dictionary
# avg_price_dict = dict(avg_price_by_group)
# plt.figure(figsize=(6, 4))
# plt.barh(list(avg_price_dict.keys()), list(avg_price_dict.values()), color=['steelblue', 'orange', '#fbceb1', 'cyan', 'pink'])

c6=round(bnb_df.groupby('neighbourhood_group')['price'].mean(),1).to_dict()
print(c6)
plt.figure(figsize=(6, 4))
plt.barh(list(c6.keys()),list(c6.values()),color=['steelblue','orange','#fbceb1','cyan','pink'])
plt.ylabel("neighbourhood group")
plt.xlabel("Avg. price")
plt.title("Average price for each neighbourhood group")
plt.show()
# Out:
# {'Bronx': 87.6, 'Brooklyn': 124.5, 'Manhattan': 196.9, 'Queens': 99.5, 'Staten Island': 114.8}

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Here we are comparing the average price for all neighbourhood group which is a categorical data hence used bar graph

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# We can conlcude from the graph that manhatten has the most expensive properties as its average price is the highest and Bronx has the lowest average price in total neighbourhood_group.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# We saw from the other graphs that staten island has the least number of properties compared to the other neighbourhood group, which in turns makes its average price high. So to reduce the average price we need to have more number of properties in that particular neighbourhood group to have a fair competition among other neighbourhood groups.

# %% [markdown]
# #### Chart - 7

# %%
# Chart - 7 visualization code
plt.figure(figsize=(10,6))
c7=sns.scatterplot(data=bnb_df,x='latitude',y='longitude',hue='neighbourhood_group',palette='Set2')
c7.set_title('Density of rooms')
c7.set_ylabel('latitude')
c7.set_xlabel('longitude')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# This graph was selected because it vividly illustrates how properties are distributed across different neighborhood groups.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From the graph data , we can seen that most densed area is manhatten and most scattered area is queens and the least densed area is staten island.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
#  It is clear that the least dense area is staten island and  it has less number of properties in itself which in turn leads to the shortage of choice for people to make in a particular area.

# %% [markdown]
# #### Chart - 8

# %%
# Chart - 8 visualization code    Host in term of their avarage price..
c8=(round(bnb_df.groupby(['host_id', 'host_name']).filter(lambda x: len(x) >= 50)
          .groupby(['host_id','host_name'])['price'].mean(),2)
          .sort_values(ascending =False).head(10).to_dict())
name1=[str(i) for i,j in c8.items()]
price1=[j for i,j in c8.items()]
plt.figure(figsize=(20, 10))
plt.barh(name1,price1)
plt.xlabel('Avg. Price')
plt.ylabel('Host id with host name')
plt.title('Top 10 host in terms of their avg. price')

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Since host name and host id are categorical data and average price is the numerical data and for depicting this appropriate graph is bar graph.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# We can easily infer from the graph that Blueground(host) has the most expensive properties than others

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# By the help of this insight we can find the most premium host as per their avg. price. so if the people wants to book a particular host and they want to check their average price so it can be clearing shown as we plot only Top 10 host. With the help of this our user searching time has been reduced that contribute for the friendly user experience.

# %% [markdown]
# #### Chart - 9

# %%
# Chart - 9 visualization code
plt.figure(figsize=(6, 6))
c9=sns.scatterplot(x='minimum_nights', y='price', data=bnb_df,hue='room_type')
plt.title('Minimum Nights vs Price')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# We used scatter plot because we wanted to show relationship between two numeric data

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
#  We were able to find from the above graph was that booking for 3 to 4 months a person will have lot of choice for the properties in airbnbs under 2000 price but above that there are limit to the properties.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# We can understand how price is varying with the minimun nights can help to make changes to have maximum revenue and occupency. For eg. for longer minimum stays are associated with lower price, so business can boost by giving longer stays with discounts and offers.

# %% [markdown]
# #### Chart - 10

# %%
# Chart - 10 visualization code

c10=(round(bnb_df.groupby(['host_id', 'host_name']).filter(lambda x: len(x) >= 50)
          .groupby(['host_id', 'host_name'])['number_of_reviews'].count(),2)
          .sort_values(ascending=False).head(10))

# %%
c10=c10.reset_index()
sns.pointplot(data=c10, x='number_of_reviews', y='host_name',color='limegreen')
plt.xlabel('Number of Reviews')
plt.ylabel('Host')
plt.title('Top 10 Hosts with Highest Number of Reviews')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Here as point plot is used as it helps in representing the estimate of central tendency for numerical variable i.e. number of reviews in this case by the showing the scatter plot points which gives indication of uncertinity around that estimate using error bars.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# We can very well understand from the graph that Sonder(NYC) is the most busiest host in terms of number of reviews then followed by Blueground and Kara etc.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# We can try to figure out what are the possible reasons for Sonder(NYC) to be the busiest in terms of reviews and what are the possible reasons people are booking their properties more so that we can ask the other host as well to make required changes.

# %% [markdown]
# #### Chart - 11

# %%
# Chart - 11 visualization code
c11=bnb_df.groupby(['neighbourhood_group','room_type'])['price'].mean().unstack()
c11.plot(kind='bar',figsize=(10,6))
plt.title('Average Price of different types of room in every neighbourhood group')
plt.ylabel('Price')
plt.xticks(rotation=0)
plt.grid(False)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# We can see that here we have numerical data as price and categorical data as the neighbourhood group and also as it is depicted for different room types as well so we used side by side bar graph.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# After understanding the data we found that the average price of entire home/apt is the highest of all the neighbourhood group

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# By understanding the graph we can say that for the neighborhood group queen ,bronx and Staten Island, private and shared room type have somewhat same average price so it may be the case that people would prefer to stay in private room category than shared one so we should either try reducing the price of shared room or increase the price of private room types.

# %% [markdown]
# #### Chart - 12

# %%
# Chart - 12 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 13 - Correlation Heatmap

# %%
bnb_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 48854 entries, 0 to 48894
# Data columns (total 14 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48854 non-null  int64
#  1   name                            48854 non-null  object
#  2   host_id                         48854 non-null  int64
#  3   host_name                       48854 non-null  object
#  4   neighbourhood_group             48854 non-null  object
#  5   neighbourhood                   48854 non-null  object
#  6   latitude                        48854 non-null  float64
#  7   longitude                       48854 non-null  float64
#  8   room_type                       48854 non-null  object
#  9   price                           48854 non-null  int64
#  10  minimum_nights                  48854 non-null  int64
#  11  number_of_reviews               48854 non-null  int64
#  12  calculated_host_listings_count  48854 non-null  int64
#  13  availability_365                48854 non-null  int64
# dtypes: float64(2), int64(7), object(5)
# memory usage: 5.6+ MB

# %%
# Correlation Heatmap visualization code
corr = bnb_df[['price','minimum_nights','calculated_host_listings_count','availability_365']].corr(method='kendall')
plt.figure(figsize=(10,5))
sns.heatmap(corr, annot=True)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# This particular graph is the most powerful visualisation as it depicts the relationship of all the columns with each other and one another too.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Here on the graph the positive values tell us about that that particular variable is directly proportional to other one corresponding to it , the negative value indicates that the variable is indirectly proportional to corresponding varibale and larger the magnitude , more is the dependency.
#
# Also 1 indicates that if you were looking at a heatmap of a variable like "minimum nights" plotted on both axes, and you saw a "1" in a cell, it would mean that when the minimum nights is high on the X-axis, it's also high on the Y-axis. When it's low on the X-axis, it's low on the Y-axis, and the relationship between these two instances of minimum nights is very strong and positive.

# %% [markdown]
# #### Chart - 14 - Pair Plot

# %%
# Pair Plot visualization code
column_name = ['price', 'minimum_nights','availability_365']
pairplot_data = bnb_df[column_name]
sns.set_palette("coolwarm",desat=0.5)
chart15=sns.pairplot(pairplot_data,kind='reg')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Here we wanted to have a pairwise visualisation of all the columns in the dataset , hence used pairplot.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Here the graph of availability_365 vs price , availability_365 vs minimum_nights, can be clearly seen that they are has strong positive dependecy i.e. directly proportional. Also the graphs price vs price, minimum_nights vs minimum_nights and availability_365 vs availability_365 the relationship between them is strong and positive.

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# *  As per the current scenario, people usually prefer to go for an entire home / apt because they prefer to put their privacy above the price of the property. So we should try investing more in renting big properties.
# *  Also, we can say that for most of the neighborhood group, private and shared room types have somewhat similar average prices so it may be the case that people would prefer to stay in the private room category than the shared one so we should either try reducing the price of the shared room or increase the price of private room types.
#
# *   We also got to know that some neighborhood groups were dense with properties whereas some had few properties i.e. were scattered which in turn led to a limit of choices for people to make before booking in a particular area, so we should also focus on including more properties there.
# *
# Through this type of analysis, we can help ourselves to make the decision wisely which is helpful to us in terms of quality and user-friendly experience.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# Throughout our analysis, we have gained a deeper understanding of various aspects of Airbnb, including pricing dynamics, geographical distribution, property types, and number of reviews.One of the key takeaways from our analysis is the importance of location in determining Airbnb rental prices. We found that certain neighborhoods and cities command higher prices, reflecting the influence of demand, local amenities, and tourist attractions. Hosts can use this information to optimize their pricing strategies, while travelers can make more informed choices based on their budget and preferences.
#
# In conclusion, our Airbnb EDA project has illuminated the complex landscape of Airbnb rentals, providing valuable insights for both hosts and travelers. By harnessing the power of Python and data analysis, we have unlocked the potential to make more informed decisions, ultimately enhancing the Airbnb experience for all parties involved. This project serves as a testament to the importance of data-driven decision-making in the modern world of hospitality and travel.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
